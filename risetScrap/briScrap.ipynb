# %%
import re
import requests
import numpy as np
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver import ActionChains
import os

# %%
import time
from IPython.display import HTML

# %%
driver = webdriver.Remote('http://13.250.162.91:4441/wd/hub', webdriver.DesiredCapabilities.FIREFOX)

# %%
link = "http://ib.bri.co.id"

# %%
driver.get(link)

# %%
time.sleep(10)
image = driver.get_screenshot_as_base64()
HTML("""<img src="data:image/png;base64,{0}">""".format(image))
# Out:
# <img src="data:image/png;base64,...">

# %%
userNameInput = driver.find_element_by_xpath('//input[@type="text"][@name="j_plain_username"]')
userNameInput.send_keys("ptarta2106")
passInput = driver.find_element_by_xpath('//input[@type="password"][@name="j_plain_password"]')
passInput.send_keys("EP879051bri")

# %%
time.sleep(5)

# %% [markdown]
# #### Masih manual

# %%
valInput = driver.find_element_by_xpath('//input[@type="text"][@name="j_code"]')
valInput.send_keys("9382")

# %%
time.sleep(10)
driver.find_element_by_xpath('//button[@type="submit"]').click()

# %%
time.sleep(10)

# %%
image = driver.get_screenshot_as_base64()
HTML("""<img src="data:image/png;base64,{0}">""".format(image))
# Out:
# <img src="data:image/png;base64,...">

# %%
parentMenu = driver.find_element_by_xpath('//div[@class="parentmenu grid"]')

# %%
time.sleep(5)
rek = parentMenu.find_element_by_xpath('//a[@id="myaccounts"]')
rek.click()

# %%
time.sleep(5)

# %%
image = driver.get_screenshot_as_base64()
HTML("""<img src="data:image/png;base64,{0}">""".format(image))
# Out:
# <img src="data:image/png;base64,...">

# %%
driver.switch_to.frame("iframemenu")

# %%
image = driver.get_screenshot_as_base64()
HTML("""<img src="data:image/png;base64,{0}">""".format(image))
# Out:
# <img src="data:image/png;base64,...">

# %%
mutasi =driver.find_element_by_xpath('//a[@href="AccountStatement.html"]')

# %%
time.sleep(5)

# %%
mutasi.click()

# %%
time.sleep(5)

# %%
driver.switch_to.default_content()

# %%
image = driver.get_screenshot_as_base64()
HTML("""<img src="data:image/png;base64,{0}">""".format(image))
# Out:
# <img src="data:image/png;base64,...">

# %%
driver.switch_to.frame("content")

# %%
image = driver.get_screenshot_as_base64()
HTML("""<img src="data:image/png;base64,{0}">""".format(image))
# Out:
# <img src="data:image/png;base64,...">

# %%
noRek = '055401000460304'

# %%
pilihRek = driver.find_element_by_xpath("//select[@id='ACCOUNT_NO']/option[@value='"+noRek+"']")

# %%
time.sleep(5)

# %%
pilihRek.click()

# %%
image = driver.get_screenshot_as_base64()
HTML("""<img src="data:image/png;base64,{0}">""".format(image))
# Out:
# <img src="data:image/png;base64,...">

# %% [markdown]
# tampilkan = driver.find_elements_by_xpath('.//input[@type="submit"][@name="submitButton"]')[0]

# %%
time.sleep(5)

# %%
driver.execute_script("return submitForm()")
# Out:
# True

# %%
time.sleep(20)

# %%
image = driver.get_screenshot_as_base64()
HTML("""<img src="data:image/png;base64,{0}">""".format(image))
# Out:
# <img src="data:image/png;base64,...">

# %% [markdown]
# ## Keluar

# %%
time.sleep(5)
driver.switch_to.default_content()
time.sleep(5)

# %%
image = driver.get_screenshot_as_base64()
HTML("""<img src="data:image/png;base64,{0}">""".format(image))
# Out:
# <img src="data:image/png;base64,...">

# %%
logout = driver.find_element_by_xpath('//a[@href="Logout.html"]')
driver.execute_script("return arguments[0].scrollIntoView(true);", logout)

# %%
image = driver.get_screenshot_as_base64()
HTML("""<img src="data:image/png;base64,{0}">""".format(image))
# Out:
# <img src="data:image/png;base64,...">

# %%
logout.click()
time.sleep(10)

# %%
driver.quit()
