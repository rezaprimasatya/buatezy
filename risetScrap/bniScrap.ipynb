# %%
import re
import requests
import numpy as np
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import os

# %%
import time
from IPython.display import HTML

# %%
driver = webdriver.Remote('http://13.250.162.91:4441/wd/hub', webdriver.DesiredCapabilities.FIREFOX)

# %%
link = "https://bnidirect.bni.co.id"

# %%
driver.get(link)

# %%
time.sleep(10)
image = driver.get_screenshot_as_base64()

# %%
HTML("""<img src="data:image/png;base64,{0}">""".format(image))
# Out:
# <img src="data:image/png;base64,...">

# %%
corpIdInput = driver.find_element_by_xpath('//input[@type="text"][@name="corpId"]')
corpIdInput.send_keys("ARTAELEKTRONIK")
userNameInput = driver.find_element_by_xpath('//input[@type="text"][@name="userName"]')
userNameInput.send_keys("HENDRABNI99")
passInput = driver.find_element_by_xpath('//input[@type="password"][@name="passwordEncryption"]')
passInput.send_keys("J0055G4n")

# %%
image = driver.get_screenshot_as_base64()
HTML("""<img src="data:image/png;base64,{0}">""".format(image))
# Out:
# <img src="data:image/png;base64,...">

# %%
time.sleep(10)
driver.find_element_by_xpath('//input[@type="button"][@name="submit1"]').click()

# %%
time.sleep(20)
image = driver.get_screenshot_as_base64()
HTML("""<img src="data:image/png;base64,{0}">""".format(image))
# Out:
# <img src="...">

# %%
mainWindow = driver.current_window_handle
popUpDashboardWindow = None
while not popUpDashboardWindow:
    for handle in driver.window_handles:
        if handle != mainWindow:
            popUpDashboardWindow = handle
            break
driver.switch_to.window(popUpDashboardWindow)

# %%
image = driver.get_screenshot_as_base64()
HTML("""<img src="data:image/png;base64,{0}">""".format(image))
# Out:
# <img src="data:image/png;base64,...">

# %%
menu = driver.find_elements_by_xpath('.//frame[@name="menuFrame"]')
main = driver.find_elements_by_xpath('.//frame[@name="mainFrame"]')

# %%
driver.switch_to.frame(menu[0])

# %%
dataMenu =driver.find_elements_by_xpath('.//div[@class="menu"]')

# %%
accountInfoPilih = dataMenu[2]
accountInfoPilih.click()

# %%
image = driver.get_screenshot_as_base64()
HTML("""<img src="data:image/png;base64,{0}">""".format(image))
# Out:
# <img src="data:image/png;base64,...">

# %%
accountInfoDropdown = driver.find_elements_by_xpath('.//span[@class="options"][@id="sub2"]')[0]

# %%
transactionInquiry = accountInfoDropdown.find_elements_by_xpath('.//div[@class="option"]')[2]
transactionInquiry.click()

# %%
time.sleep(10)
driver.switch_to.window(popUpDashboardWindow)
driver.switch_to.default_content()

# %%
image = driver.get_screenshot_as_base64()
HTML("""<img src="data:image/png;base64,{0}">""".format(image))
# Out:
# <img src="data:image/png;base64,...">

# %%
driver.switch_to.frame(main[0])

# %%
image = driver.get_screenshot_as_base64()
HTML("""<img src="data:image/png;base64,{0}">""".format(image))
# Out:
# <img src="data:image/png;base64,...">

# %%
pilihRek = driver.find_elements_by_xpath('.//a[@href="#"]/img[@src="/common/image/picklist.gif"]')[0]
pilihRek.click()
time.sleep(10)

# %%
image = driver.get_screenshot_as_base64()
HTML("""<img src="data:image/png;base64,{0}">""".format(image))
# Out:
# <img src="data:image/png;base64,...">

# %%
popUpRekWindow = None
while not popUpRekWindow:
    for handle in driver.window_handles:
        if (handle != mainWindow) and (handle != popUpDashboardWindow):
            popUpRekWindow = handle
            break
driver.switch_to.window(popUpRekWindow)
time.sleep(10)

# %%
image = driver.get_screenshot_as_base64()
HTML("""<img src="data:image/png;base64,{0}">""".format(image))
# Out:
# <img src="data:image/png;base64,...">

# %%
NoRekPilih = driver.find_element_by_link_text("8000077995")
NoRekPilih.click()
time.sleep(10)

# %%
driver.switch_to.window(popUpDashboardWindow)
driver.switch_to.default_content()

# %%
image = driver.get_screenshot_as_base64()
HTML("""<img src="data:image/png;base64,{0}">""".format(image))
# Out:
# <img src="data:image/png;base64,...">

# %%
driver.switch_to.frame(main[0])
tombolShow = driver.find_elements_by_xpath('.//input[@type="button"][@name="show1"]')[0]
tombolShow.click()
time.sleep(10)

# %%
popUpMutasiWindow = None
while not popUpMutasiWindow:
    for handle in driver.window_handles:
        if (handle != mainWindow) and (handle != popUpDashboardWindow) and (handle != popUpRekWindow):
            popUpMutasiWindow = handle
            break
driver.switch_to.window(popUpMutasiWindow)

# %%
image = driver.get_screenshot_as_base64()
HTML("""<img src="data:image/png;base64,{0}">""".format(image))
# Out:
# <img src="data:image/png;base64,...">

# %%
driver.close()

# %% [markdown]
# ## Keluar

# %%
driver.switch_to.window(popUpDashboardWindow)
driver.switch_to.default_content()

# %%
image = driver.get_screenshot_as_base64()
HTML("""<img src="data:image/png;base64,{0}">""".format(image))
# Out:
# <img src="data:image/png;base64,...">

# %%
driver.switch_to.frame(menu[0])

# %%
logOff = driver.find_element_by_css_selector("a[href='/corp/common/login.do?action=logout']")
logOff.click()

# %%
driver.quit()
