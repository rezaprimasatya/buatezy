# %%
import re
import requests
import numpy as np
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import os

# %%
import time
from IPython.display import HTML

# %%
driver = webdriver.Remote('http://13.250.162.91:4441/wd/hub', webdriver.DesiredCapabilities.FIREFOX)

# %%
link = "https://mib.bankmandiri.co.id/sme/common/login.do?action=logoutSME"

# %%
driver.get(link)

# %%
time.sleep(10)
image = driver.get_screenshot_as_base64()
HTML("""<img src="data:image/png;base64,{0}">""".format(image))
# Out:
# <img src="data:image/png;base64,...">

# %%
corpIdInput = driver.find_element_by_xpath('//input[@type="text"][@name="corpId"]')
corpIdInput.send_keys("FC45794")
userNameInput = driver.find_element_by_xpath('//input[@type="text"][@name="userName"]')
userNameInput.send_keys("EZYPAY9999")
passInput = driver.find_element_by_xpath('//input[@type="password"][@name="passwordEncryption"]')
passInput.send_keys("879051eP")

# %%
image = driver.get_screenshot_as_base64()
HTML("""<img src="data:image/png;base64,{0}">""".format(image))
# Out:
# <img src="data:image/png;base64,...">

# %%
time.sleep(10)
driver.find_element_by_xpath('//input[@type="submit"][@value="Login"]').click()

# %%
time.sleep(20)
image = driver.get_screenshot_as_base64()
HTML("""<img src="data:image/png;base64,{0}">""".format(image))
# Out:
# <img src="data:image/png;base64,...">

# %%
frame = driver.find_elements_by_xpath('.//frame')

# %%
header = frame[0]
menu = frame[1]
main = frame[2]

# %%
driver.switch_to.frame(menu)

# %%
image = driver.get_screenshot_as_base64()
HTML("""<img src="data:image/png;base64,{0}">""".format(image))
# Out:
# <img src="data:image/png;base64,...">

# %%
dataMenu =driver.find_elements_by_xpath('.//div[@class="silverheader"]')

# %%
infoRek = dataMenu[3]
infoRek.click()

# %%
image = driver.get_screenshot_as_base64()
HTML("""<img src="data:image/png;base64,{0}">""".format(image))
# Out:
# <img src="data:image/png;base64,...">

# %%
transactionInquiry = driver.find_element_by_link_text("Mutasi Rekening")
transactionInquiry.click()

# %%
driver.switch_to.default_content()
driver.switch_to.frame(main)
image = driver.get_screenshot_as_base64()
HTML("""<img src="data:image/png;base64,{0}">""".format(image))
# Out:
# <img src="data:image/png;base64,...">

# %%
tampilkan = driver.find_elements_by_xpath('.//input[@type="button"][@name="show1"]')[0]
tampilkan.click()

# %%
image = driver.get_screenshot_as_base64()
HTML("""<img src="data:image/png;base64,{0}">""".format(image))
# Out:
# <img src="data:image/png;base64,...">

# %% [markdown]
# ## Keluar

# %%
driver.switch_to.default_content()
driver.switch_to.frame(frame[0])

# %%
logOff = driver.find_elements_by_xpath('.//tr/td[@class="top_nav_right"]')

# %%
logOff[0].click()
time.sleep(10)

# %%
driver.quit()
